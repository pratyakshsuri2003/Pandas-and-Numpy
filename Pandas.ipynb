# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("F:/ML Predictor/matches.csv")

# %%
data.head()
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
data.tail() #-> used to get last 5 rows of the dataset
# Out:
#       id  season       city        date                team1  \
# 572  573    2016     Raipur  2016-05-22     Delhi Daredevils
# 573  574    2016  Bangalore  2016-05-24        Gujarat Lions
# 574  575    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 575  576    2016      Delhi  2016-05-27        Gujarat Lions
# 576  577    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 572  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 573  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 574        Kolkata Knight Riders        Kolkata Knight Riders         field
# 575          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 576  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 572  normal           0  Royal Challengers Bangalore            0
# ...

# %%
data.shape #-> gives the count of rows and columns in the dataset
# Out:
# (577, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               577 non-null    int64
#  1   season           577 non-null    int64
#  2   city             570 non-null    object
#  3   date             577 non-null    object
#  4   team1            577 non-null    object
#  5   team2            577 non-null    object
#  6   toss_winner      577 non-null    object
#  7   toss_decision    577 non-null    object
#  8   result           577 non-null    object
#  9   dl_applied       577 non-null    int64
#  10  winner           574 non-null    object
#  11  win_by_runs      577 non-null    int64
#  12  win_by_wickets   577 non-null    int64
#  13  player_of_match  574 non-null    object
#  14  venue            577 non-null    object
#  15  umpire1          577 non-null    object
#  16  umpire2          577 non-null    object
# ...

# %%
data.describe() #-> works with numerical values only
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  577.000000   577.000000  577.000000   577.000000      577.000000
# mean   289.000000  2012.029463    0.025997    13.715771        3.363951
# std    166.709828     2.486247    0.159263    23.619282        3.416049
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    145.000000  2010.000000    0.000000     0.000000        0.000000
# 50%    289.000000  2012.000000    0.000000     0.000000        3.000000
# 75%    433.000000  2014.000000    0.000000    20.000000        6.000000
# max    577.000000  2016.000000    1.000000   144.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
data['team1']
# Out:
# 0      Kolkata Knight Riders
# 1        Chennai Super Kings
# 2           Rajasthan Royals
# 3             Mumbai Indians
# 4            Deccan Chargers
#                ...
# 572         Delhi Daredevils
# 573            Gujarat Lions
# 574      Sunrisers Hyderabad
# 575            Gujarat Lions
# 576      Sunrisers Hyderabad
# Name: team1, Length: 577, dtype: object

# %%
data[['team1', 'team2', 'winner']]
# Out:
#                      team1                        team2  \
# 0    Kolkata Knight Riders  Royal Challengers Bangalore
# 1      Chennai Super Kings              Kings XI Punjab
# 2         Rajasthan Royals             Delhi Daredevils
# 3           Mumbai Indians  Royal Challengers Bangalore
# 4          Deccan Chargers        Kolkata Knight Riders
# ..                     ...                          ...
# 572       Delhi Daredevils  Royal Challengers Bangalore
# 573          Gujarat Lions  Royal Challengers Bangalore
# 574    Sunrisers Hyderabad        Kolkata Knight Riders
# 575          Gujarat Lions          Sunrisers Hyderabad
# 576    Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0          Kolkata Knight Riders
# 1            Chennai Super Kings
# 2               Delhi Daredevils
# 3    Royal Challengers Bangalore
# 4          Kolkata Knight Riders
# ..                           ...
# 572  Royal Challengers Bangalore
# ...

# %%
data.iloc[1:6]
# Out:
#    id  season        city        date                team1  \
# 1   2    2008  Chandigarh  2008-04-19  Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19     Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20       Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20      Deccan Chargers
# 5   6    2008      Jaipur  2008-04-21      Kings XI Punjab
#
#                          team2          toss_winner toss_decision  result  \
# 1              Kings XI Punjab  Chennai Super Kings           bat  normal
# 2             Delhi Daredevils     Rajasthan Royals           bat  normal
# 3  Royal Challengers Bangalore       Mumbai Indians           bat  normal
# 4        Kolkata Knight Riders      Deccan Chargers           bat  normal
# 5             Rajasthan Royals      Kings XI Punjab           bat  normal
#
#    dl_applied                       winner  win_by_runs  win_by_wickets  \
# 1           0          Chennai Super Kings           33               0
# ...

# %%
data.iloc[:,[4, 5, 10]]
# Out:
#                      team1                        team2  \
# 0    Kolkata Knight Riders  Royal Challengers Bangalore
# 1      Chennai Super Kings              Kings XI Punjab
# 2         Rajasthan Royals             Delhi Daredevils
# 3           Mumbai Indians  Royal Challengers Bangalore
# 4          Deccan Chargers        Kolkata Knight Riders
# ..                     ...                          ...
# 572       Delhi Daredevils  Royal Challengers Bangalore
# 573          Gujarat Lions  Royal Challengers Bangalore
# 574    Sunrisers Hyderabad        Kolkata Knight Riders
# 575          Gujarat Lions          Sunrisers Hyderabad
# 576    Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0          Kolkata Knight Riders
# 1            Chennai Super Kings
# 2               Delhi Daredevils
# 3    Royal Challengers Bangalore
# 4          Kolkata Knight Riders
# ..                           ...
# 572  Royal Challengers Bangalore
# ...

# %%
mask = data['city']=='Hyderabad'

# %%
data[mask].shape
# Out:
# (41, 18)

# %%
def count_matches_in_cities(city):
    mask = data['city'] == city
    return data[mask].shape[0]

# %%
count_matches_in_cities('Chennai')
# Out:
# 48

# %%
def count_match_in_city_after_twozerotwozero(city):
    mask1 = data['city'] == city
    mask2 = data['date'] >= '2010-01-01'
    mask3 =  data[mask1 & mask2]
    return mask3.shape[0]

# %%
count_match_in_city_after_twozerotwozero("Hyderabad")
# Out:
# 34

# %%
data['winner'].value_counts()
# Out:
# Mumbai Indians                 80
# Chennai Super Kings            79
# Royal Challengers Bangalore    70
# Kolkata Knight Riders          68
# Rajasthan Royals               63
# Kings XI Punjab                63
# Delhi Daredevils               56
# Sunrisers Hyderabad            34
# Deccan Chargers                29
# Pune Warriors                  12
# Gujarat Lions                   9
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
data['winner'].value_counts()
# Out:
# Mumbai Indians                 80
# Chennai Super Kings            79
# Royal Challengers Bangalore    70
# Kolkata Knight Riders          68
# Rajasthan Royals               63
# Kings XI Punjab                63
# Delhi Daredevils               56
# Sunrisers Hyderabad            34
# Deccan Chargers                29
# Pune Warriors                  12
# Gujarat Lions                   9
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data['winner'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
data['winner'].value_counts().plot(kind="barh")

# %%
import matplotlib.pyplot as plt
x = data['winner'].value_counts()
y = data['team1'].value_counts()
plt.plot(x, y)
plt.show()

# %%
data['toss_decision'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='toss_decision'>

# %% [markdown]
# # series operation

# %%
my_series = data['winner'].value_counts()

# %%
my_series
# Out:
# Mumbai Indians                 80
# Chennai Super Kings            79
# Royal Challengers Bangalore    70
# Kolkata Knight Riders          68
# Rajasthan Royals               63
# Kings XI Punjab                63
# Delhi Daredevils               56
# Sunrisers Hyderabad            34
# Deccan Chargers                29
# Pune Warriors                  12
# Gujarat Lions                   9
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
my_series.index  # index is a attribute
# Out:
# Index(['Mumbai Indians', 'Chennai Super Kings', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Rajasthan Royals', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Sunrisers Hyderabad', 'Deccan Chargers',
#        'Pune Warriors', 'Gujarat Lions', 'Kochi Tuskers Kerala',
#        'Rising Pune Supergiants'],
#       dtype='object')

# %%
my_series.values # values are also attribute
# Out:
# array([80, 79, 70, 68, 63, 63, 56, 34, 29, 12,  9,  6,  5], dtype=int64)

# %%
my_series['Gujarat Lions']
# Out:
# 9

# %%
data['team1'].value_counts() + data['team2'].value_counts()
# Out:
# Chennai Super Kings            131
# Deccan Chargers                 75
# Delhi Daredevils               133
# Gujarat Lions                   16
# Kings XI Punjab                134
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          132
# Mumbai Indians                 140
# Pune Warriors                   46
# Rajasthan Royals               118
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    139
# Sunrisers Hyderabad             62
# dtype: int64

# %%
# sort_values()

# %%
((data['team1'].value_counts() + data['team2'].value_counts()).sort_values(ascending=False)).head()
# Out:
# Mumbai Indians                 140
# Royal Challengers Bangalore    139
# Kings XI Punjab                134
# Delhi Daredevils               133
# Kolkata Knight Riders          132
# dtype: int64

# %%
data.sort_values('city', ascending = False, inplace=True)

# %%
data
# Out:
#       id  season           city        date                        team1  \
# 471  472    2015  Visakhapatnam  2015-04-18             Delhi Daredevils
# 469  470    2015  Visakhapatnam  2015-04-16          Sunrisers Hyderabad
# 477  478    2015  Visakhapatnam  2015-04-22          Sunrisers Hyderabad
# 563  564    2016  Visakhapatnam  2016-05-15               Mumbai Indians
# 565  566    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# ..   ...     ...            ...         ...                          ...
# 407  408    2014            NaN  2014-04-23          Chennai Super Kings
# 409  410    2014            NaN  2014-04-25          Sunrisers Hyderabad
# 410  411    2014            NaN  2014-04-25               Mumbai Indians
# 415  416    2014            NaN  2014-04-28  Royal Challengers Bangalore
# 417  418    2014            NaN  2014-04-30          Sunrisers Hyderabad
#
#                        team2              toss_winner toss_decision  result  \
# ...

# %%
data.sort_values(['city', 'date'], inplace=True)

# %%
data.head()
# Out:
#       id  season       city        date                  team1  \
# 398  399    2014  Abu Dhabi  2014-04-16  Kolkata Knight Riders
# 401  402    2014  Abu Dhabi  2014-04-18    Sunrisers Hyderabad
# 400  401    2014  Abu Dhabi  2014-04-18    Chennai Super Kings
# 405  406    2014  Abu Dhabi  2014-04-21    Chennai Super Kings
# 412  413    2014  Abu Dhabi  2014-04-26        Kings XI Punjab
#
#                      team2            toss_winner toss_decision  result  \
# 398         Mumbai Indians  Kolkata Knight Riders           bat  normal
# 401       Rajasthan Royals       Rajasthan Royals         field  normal
# 400        Kings XI Punjab    Chennai Super Kings           bat  normal
# 405       Delhi Daredevils    Chennai Super Kings           bat  normal
# 412  Kolkata Knight Riders  Kolkata Knight Riders         field  normal
#
#      dl_applied                 winner  win_by_runs  win_by_wickets  \
# 398           0  Kolkata Knight Riders           41               0
# ...

# %%
# i need city in ascending order but data in descending order

# %%
data.sort_values(['city', 'date'], ascending = [True, False], inplace=True)

# %%
data.sort_values('win_by_runs', ascending = False)
# Out:
#       id  season        city        date                        team1  \
# 560  561    2016   Bangalore  2016-05-14  Royal Challengers Bangalore
# 0      1    2008   Bangalore  2008-04-18        Kolkata Knight Riders
# 497  498    2015   Bangalore  2015-05-06  Royal Challengers Bangalore
# 351  352    2013   Bangalore  2013-04-23  Royal Challengers Bangalore
# 236  237    2011  Dharamsala  2011-05-17              Kings XI Punjab
# ..   ...     ...         ...         ...                          ...
# 165  166    2010  Dharamsala  2010-04-16              Kings XI Punjab
# 168  169    2010  Dharamsala  2010-04-18              Kings XI Punjab
# 311  312    2012  Dharamsala  2012-05-17          Chennai Super Kings
# 314  315    2012  Dharamsala  2012-05-19              Kings XI Punjab
# 403  404    2014         NaN  2014-04-19        Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
# drop duplicates()

# %%
df = data.duplicated(['city'])

# %%
df = data[data.duplicated(['city'])]

# %%
df
# Out:
#       id  season       city        date                        team1  \
# 412  413    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 411  412    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 405  406    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 401  402    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 400  401    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# ..   ...     ...        ...         ...                          ...
# 409  410    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 410  411    2014        NaN  2014-04-25               Mumbai Indians
# 407  408    2014        NaN  2014-04-23          Chennai Super Kings
# 402  403    2014        NaN  2014-04-19               Mumbai Indians
# 403  404    2014        NaN  2014-04-19        Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.shape
# Out:
# (546, 18)

# %%
df2 = df.drop_duplicates(['city'])

# %%
df2
# Out:
#       id  season            city        date                        team1  \
# 412  413    2014       Abu Dhabi  2014-04-26              Kings XI Punjab
# 476  477    2015       Ahmedabad  2015-04-21             Rajasthan Royals
# 573  574    2016       Bangalore  2016-05-24                Gujarat Lions
# 101  102    2009    Bloemfontein  2009-05-15             Delhi Daredevils
# 66    67    2009       Cape Town  2009-04-23             Rajasthan Royals
# 110  111    2009       Centurion  2009-05-21               Mumbai Indians
# 555  556    2016      Chandigarh  2016-05-09  Royal Challengers Bangalore
# 499  500    2015         Chennai  2015-05-08          Chennai Super Kings
# 431  432    2014         Cuttack  2014-05-11              Kings XI Punjab
# 574  575    2016           Delhi  2016-05-25          Sunrisers Hyderabad
# 352  353    2013      Dharamsala  2013-05-16              Kings XI Punjab
# 108  109    2009          Durban  2009-05-20             Rajasthan Royals
# ...

# %%
df2.shape
# Out:
# (31, 18)

# %%
df3 = data.duplicated('toss_decision')

# %%
df3
# Out:
# 416    False
# 412    False
# 411     True
# 405     True
# 401     True
#        ...
# 409     True
# 410     True
# 407     True
# 402     True
# 403     True
# Length: 577, dtype: bool

# %%
df3 = data.drop_duplicates('toss_decision')

# %%
df3
# Out:
#       id  season       city        date             team1  \
# 416  417    2014  Abu Dhabi  2014-04-29  Rajasthan Royals
# 412  413    2014  Abu Dhabi  2014-04-26   Kings XI Punjab
#
#                      team2            toss_winner toss_decision  result  \
# 416  Kolkata Knight Riders       Rajasthan Royals           bat     tie
# 412  Kolkata Knight Riders  Kolkata Knight Riders         field  normal
#
#      dl_applied            winner  win_by_runs  win_by_wickets  \
# 416           0  Rajasthan Royals            0               0
# 412           0   Kings XI Punjab           23               0
#
#     player_of_match                 venue          umpire1         umpire2  \
# 416     JP Faulkner  Sheikh Zayed Stadium        Aleem Dar    AK Chaudhary
# 412  Sandeep Sharma  Sheikh Zayed Stadium  HDPK Dharmasena  RK Illingworth
#
#      umpire3
# 416      NaN
# 412      NaN

# %%
df3.shape
# Out:
# (2, 18)

# %%
df4 = data.drop_duplicates('season')[['season', 'winner', 'player_of_match', 'umpire1']].sort_values('season', ascending = False)
df4
# Out:
#      season                       winner player_of_match          umpire1
# 576    2016          Sunrisers Hyderabad     BCJ Cutting  HDPK Dharmasena
# 480    2015  Royal Challengers Bangalore        MA Starc        M Erasmus
# 416    2014             Rajasthan Royals     JP Faulkner        Aleem Dar
# 392    2013  Royal Challengers Bangalore         V Kohli    C Shamshuddin
# 319    2012          Chennai Super Kings        MS Dhoni        BF Bowden
# 242    2011  Royal Challengers Bangalore        CH Gayle      K Hariharan
# 138    2010             Rajasthan Royals         NV Ojha        SS Hazare
# 105    2009             Delhi Daredevils  AB de Villiers        SS Hazare
# 30     2008               Mumbai Indians    CRD Fernando        BF Bowden

# %%
# groupby

# %%
df10 = data.groupby('winner')

# %%
df10.size().sort_values(ascending= False)
# Out:
# winner
# Mumbai Indians                 80
# Chennai Super Kings            79
# Royal Challengers Bangalore    70
# Kolkata Knight Riders          68
# Kings XI Punjab                63
# Rajasthan Royals               63
# Delhi Daredevils               56
# Sunrisers Hyderabad            34
# Deccan Chargers                29
# Pune Warriors                  12
# Gujarat Lions                   9
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# dtype: int64

# %%
df10.first().shape
# Out:
# (13, 17)

# %%
df10.groups
# Out:
# {'Chennai Super Kings': [405, 478, 450, 319, 14, 89, 77, 509, 331, 1, 503, 494, 487, 482, 461, 459, 386, 365, 358, 354, 350, 336, 320, 304, 292, 274, 272, 260, 247, 237, 229, 216, 212, 202, 188, 175, 162, 151, 146, 142, 31, 11, 7, 423, 394, 344, 125, 27, 168, 109, 84, 375, 54, 301, 225, 81, 92, 346, 308, 122, 43, 470, 455, 430, 244, 204, 174, 172, 56, 102, 62, 362, 515, 434, 418, 414, 253, 410, 407], 'Deccan Chargers': [154, 64, 61, 112, 87, 119, 25, 288, 129, 126, 193, 169, 240, 165, 71, 68, 316, 313, 185, 114, 103, 95, 205, 235, 232, 12, 160, 156, 281], 'Delhi Daredevils': [120, 527, 137, 44, 105, 60, 110, 76, 117, 164, 19, 542, 533, 523, 488, 479, 348, 309, 285, 282, 263, 258, 199, 149, 143, 140, 49, 38, 16, 2, 314, 98, 86, 65, 90, 558, 271, 219, 6, 289, 94, 209, 249, 267, 190, 69, 468, 279, 568, 505, 364, 359, 547, 413, 471, 403], 'Gujarat Lions': [519, 539, 570, 567, 554, 525, 541, 535, 522], 'Kings XI Punjab': [412, 400, 476, 428, 369, 290, 24, 101, 70, 552, 526, 506, 452, 449,
# ...

# %%
df10.get_group('Kolkata Knight Riders')
# Out:
#       id  season       city        date                        team1  \
# 398  399    2014  Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 546  547    2016  Bangalore  2016-05-02  Royal Challengers Bangalore
# 457  458    2014  Bangalore  2014-06-01              Kings XI Punjab
# 257  258    2012  Bangalore  2012-04-10        Kolkata Knight Riders
# 0      1    2008  Bangalore  2008-04-18        Kolkata Knight Riders
# ..   ...     ...        ...         ...                          ...
# 377  378    2013       Pune  2013-05-09        Kolkata Knight Riders
# 318  319    2012       Pune  2012-05-22        Kolkata Knight Riders
# 315  316    2012       Pune  2012-05-19        Kolkata Knight Riders
# 381  382    2013     Ranchi  2013-05-12  Royal Challengers Bangalore
# 408  409    2014    Sharjah  2014-04-24        Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df10[['win_by_runs', 'win_by_wickets']].sum().sort_values(['win_by_runs','win_by_wickets'], ascending = False)
# Out:
#                              win_by_runs  win_by_wickets
# winner
# Chennai Super Kings                 1587             208
# Mumbai Indians                      1362             233
# Royal Challengers Bangalore         1150             277
# Rajasthan Royals                     821             233
# Kolkata Knight Riders                798             242
# Kings XI Punjab                      796             203
# Deccan Chargers                      421              72
# Delhi Daredevils                     416             253
# Sunrisers Hyderabad                  347              93
# Pune Warriors                        139              36
# Rising Pune Supergiants               53              20
# Kochi Tuskers Kerala                  23              30
# Gujarat Lions                          1              41

# %%
# isin()

# %%
# find the most destructive batsman in the history of IPL in strike rate = n of runs/n of balls
# min batsman 200 balls in over 16-20

# %%
import pandas as pd
# data.groupby('')

# %%
india_weather=pd.DataFrame({
    "city": ["mumbai", "Delhi", "Banglore"],
    "Temperature": [23, 45, 67],
    "humidity": [12, 67, 89],
    "fog": [69, 53, 88],
    "other": [30, 15, 22]
})
india_weather
# Out:
#        city  Temperature  humidity  fog  other
# 0    mumbai           23        12   69     30
# 1     Delhi           45        67   53     15
# 2  Banglore           67        89   88     22

# %%
us_weather=pd.DataFrame({
    "city": ["new york", "ohio", "chicago"],
    "Temperature": [13, 34, 23],
    "humidity": [28, 78, 56],
    "fog": [67, 32, 98],
    "other": [19, 35, 22]
})
us_weather
# Out:
#        city  Temperature  humidity  fog  other
# 0  new york           13        28   67     19
# 1      ohio           34        78   32     35
# 2   chicago           23        56   98     22

# %%
pd.concat([india_weather, us_weather])
# Out:
#        city  Temperature  humidity  fog  other
# 0    mumbai           23        12   69     30
# 1     Delhi           45        67   53     15
# 2  Banglore           67        89   88     22
# 0  new york           13        28   67     19
# 1      ohio           34        78   32     35
# 2   chicago           23        56   98     22

# %%
pd.concat([india_weather, us_weather], ignore_index=True)
# Out:
#        city  Temperature  humidity  fog  other
# 0    mumbai           23        12   69     30
# 1     Delhi           45        67   53     15
# 2  Banglore           67        89   88     22
# 3  new york           13        28   67     19
# 4      ohio           34        78   32     35
# 5   chicago           23        56   98     22

# %%
df = pd.concat([india_weather, us_weather], keys=['india', 'us'])
df
# Out:
#              city  Temperature  humidity  fog  other
# india 0    mumbai           23        12   69     30
#       1     Delhi           45        67   53     15
#       2  Banglore           67        89   88     22
# us    0  new york           13        28   67     19
#       1      ohio           34        78   32     35
#       2   chicago           23        56   98     22

# %%
df.loc["us"]
# Out:
#        city  Temperature  humidity  fog  other
# 0  new york           13        28   67     19
# 1      ohio           34        78   32     35
# 2   chicago           23        56   98     22

# %%
temperature_df = pd.DataFrame({
    "city": ["mumbai", "Delhi", "Banglore"],
    "temperature": [45, 23, 56]
})
temperature_df
# Out:
#        city  temperature
# 0    mumbai           45
# 1     Delhi           23
# 2  Banglore           56

# %%
windspeed_df = pd.DataFrame({
    "city": ["mumbai", "Delhi", "Banglore"],
    "windspeed": [7, 13, 6]
})
windspeed_df
# Out:
#        city  windspeed
# 0    mumbai          7
# 1     Delhi         13
# 2  Banglore          6

# %%
df = pd.concat([temperature_df, windspeed_df], axis=1)
df
# Out:
#        city  temperature      city  windspeed
# 0    mumbai           45    mumbai          7
# 1     Delhi           23     Delhi         13
# 2  Banglore           56  Banglore          6

# %%
s = pd.Series(["Rain", "Dry", "HUmid"], name="event")
s
# Out:
# 0     Rain
# 1      Dry
# 2    HUmid
# Name: event, dtype: object

# %%
pd.concat([temperature_df, s], axis=1)
# Out:
#        city  temperature  event
# 0    mumbai           45   Rain
# 1     Delhi           23    Dry
# 2  Banglore           56  HUmid

# %%
newdf = india_weather.drop("fog", axis='columns')

# %%
newdf
# Out:
#        city  Temperature  humidity  other
# 0    mumbai           23        12    190
# 1     Delhi           45        67    345
# 2  Banglore           67        89    222

# %%
india_weather
# Out:
#        city  Temperature  humidity
# 0    mumbai           23        12
# 1     Delhi           45        67
# 2  Banglore           67        89

# %% [markdown]
# ### Merge

# %%
pd.merge(temperature_df, windspeed_df, on="city")
# Out:
#        city  temperature  windspeed
# 0    mumbai           45          7
# 1     Delhi           23         13
# 2  Banglore           56          6

# %%
df4=pd.DataFrame({
    "city": ["new york", "hamilton", "chicago", "washington"],
    "Temperature": [13, 34, 23, 67],
})
df4
# Out:
#          city  Temperature
# 0    new york           13
# 1    hamilton           34
# 2     chicago           23
# 3  washington           67

# %%
df5=pd.DataFrame({
    "city": ["new york", "ohio", "chicago"],
    "humidity": [28, 78, 56],
})
df5
# Out:
#        city  humidity
# 0  new york        28
# 1      ohio        78
# 2   chicago        56

# %%
df6 = pd.merge(df4, df5, on="city") # INNER JOIN
df6
# Out:
#        city  Temperature  humidity
# 0  new york           13        28
# 1   chicago           23        56

# %%
df7 = pd.merge(df4, df5, on="city", how = "outer") # Outer JOIN
df7
# Out:
#          city  Temperature  humidity
# 0    new york         13.0      28.0
# 1    hamilton         34.0       NaN
# 2     chicago         23.0      56.0
# 3  washington         67.0       NaN
# 4        ohio          NaN      78.0

# %%
df8 = pd.merge(df4, df5, on="city", how = "left") # LEFT JOIN
df8
# Out:
#          city  Temperature  humidity
# 0    new york           13      28.0
# 1    hamilton           34       NaN
# 2     chicago           23      56.0
# 3  washington           67       NaN

# %%
df9 = pd.merge(df4, df5, on="city", how = "right") # RIGHT JOIN
df9
# Out:
#        city  Temperature  humidity
# 0  new york         13.0        28
# 1      ohio          NaN        78
# 2   chicago         23.0        56

# %%
# if you abt find the data come from which table so you can use (indicator = True)

# %%
df10 = pd.merge(df4, df5, on="city", how = "left", indicator=True) # LEFT JOIN
df10
# Out:
#          city  Temperature  humidity     _merge
# 0    new york           13      28.0       both
# 1    hamilton           34       NaN  left_only
# 2     chicago           23      56.0       both
# 3  washington           67       NaN  left_only

# %% [markdown]
# ## suffixes

# %% [markdown]
# ## Data Reshaping Technique

# %% [markdown]
# #### pivot() allows us to transform or reshape data

# %%
import pandas as pd
df = pd.DataFrame({
    "date": ["5/1/2017", "5/2/2017", "5/3/2017", "5/1/2017", "5/2/2017", "5/3/2017", "5/1/2017", "5/2/2017", "5/3/2017"],
    "city": ["new york", "new york", "new york", "mumbai", "mumbai", "mumbai", "beijing", "beijing", "beijing"],
    "temperature": [65, 65, 68, 75, 78, 82, 80, 77, 79],
    "humidity": [56, 58, 60, 80, 83, 85, 26, 30, 35]
})
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           65        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df.pivot(index="city", columns="date", values="humidity")
# Out:
# date      5/1/2017  5/2/2017  5/3/2017
# city
# beijing         26        30        35
# mumbai          80        83        85
# new york        56        58        60

# %% [markdown]
# #### pivot table is used to summerize and aggregate data inside dataframe

# %%
df.pivot_table(index="city", columns="date")
# Out:
#          humidity                   temperature
# date     5/1/2017 5/2/2017 5/3/2017    5/1/2017 5/2/2017 5/3/2017
# city
# beijing        26       30       35          80       77       79
# mumbai         80       83       85          75       78       82
# new york       56       58       60          65       65       68

# %%
df.pivot_table(index="city", columns="date", aggfunc="mean")
# Out:
#          humidity                   temperature
# date     5/1/2017 5/2/2017 5/3/2017    5/1/2017 5/2/2017 5/3/2017
# city
# beijing        26       30       35          80       77       79
# mumbai         80       83       85          75       78       82
# new york       56       58       60          65       65       68

# %%
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           65        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df2 = pd.DataFrame({
    "date": ["5/1/2017", "5/2/2017", "5/3/2017", "12/1/2017", "12/2/2017", "12/3/2017"],
    "city": ["new york", "new york", "new york", "new year", "new year", "new year"],
    "temperature": [65, 65, 68, 75, 78, 82],
    "humidity": [56, 58, 60, 80, 83, 85]
})
df2
# Out:
#         date      city  temperature  humidity
# 0   5/1/2017  new york           65        56
# 1   5/2/2017  new york           65        58
# 2   5/3/2017  new york           68        60
# 3  12/1/2017  new year           75        80
# 4  12/2/2017  new year           78        83
# 5  12/3/2017  new year           82        85

# %%
type(df2["date"][0])
# Out:
# str

# %%
df2["date"] = pd.to_datetime(df2["date"])

# %%
df2
# Out:
#         date      city  temperature  humidity
# 0 2017-05-01  new york           65        56
# 1 2017-05-02  new york           65        58
# 2 2017-05-03  new york           68        60
# 3 2017-12-01  new year           75        80
# 4 2017-12-02  new year           78        83
# 5 2017-12-03  new year           82        85

# %%
type(df2["date"][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df2.pivot_table(index=pd.Grouper(freq="M", key="date"), columns = "city")
# Out:
#              humidity          temperature
# city         new year new york    new year new york
# date
# 2017-05-31        NaN     58.0         NaN     66.0
# 2017-12-31  82.666667      NaN   78.333333      NaN

# %% [markdown]
# ### melt is used to transform or reshape data

# %%
import pandas as pd
gfg = pd.read_csv("F:/ML Predictor/weather123.csv")
gfg
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   Thursday       22       82      38
# 4     Friday       30       83      30
# 5   Saturday       20       81      45
# 6     Sunday       25       77      47

# %%
gfg = pd.melt(gfg, id_vars=["day"])
gfg
# Out:
#           day variable  value
# 0      Monday  chicago     32
# 1     Tuesday  chicago     30
# 2   Wednesday  chicago     28
# 3    Thursday  chicago     22
# 4      Friday  chicago     30
# 5    Saturday  chicago     20
# 6      Sunday  chicago     25
# 7      Monday  chennai     75
# 8     Tuesday  chennai     77
# 9   Wednesday  chennai     75
# 10   Thursday  chennai     82
# 11     Friday  chennai     83
# 12   Saturday  chennai     81
# 13     Sunday  chennai     77
# 14     Monday   berlin     41
# 15    Tuesday   berlin     43
# 16  Wednesday   berlin     45
# 17   Thursday   berlin     38
# 18     Friday   berlin     30
# 19   Saturday   berlin     45
# 20     Sunday   berlin     47

# %%
gfg2 = pd.melt(gfg, id_vars="day", var_name="city", value_name="temperature")
gfg2
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_1712\3729902703.py:1: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   gfg2 = pd.melt(gfg, id_vars="day", var_name="city", value_name="temperature")
#                 day         city temperature
# 0            Monday         city        city
# 1           Tuesday         city        city
# 2         Wednesday         city        city
# 3          Thursday         city        city
# 4            Friday         city        city
# ...             ...          ...         ...
# 11010043  Wednesday  temperature          45
# 11010044   Thursday  temperature          38
# 11010045     Friday  temperature          30
# 11010046   Saturday  temperature          45
# 11010047     Sunday  temperature          47
#
# [11010048 rows x 3 columns]

# %%
gfg2.drop_duplicates(inplace  = True)
gfg2
# Out:
#                 day         city temperature
# 0            Monday         city        city
# 1           Tuesday         city        city
# 2         Wednesday         city        city
# 3          Thursday         city        city
# 4            Friday         city        city
# ...             ...          ...         ...
# 11010042    Tuesday  temperature          43
# 11010043  Wednesday  temperature          45
# 11010044   Thursday  temperature          38
# 11010046   Saturday  temperature          45
# 11010047     Sunday  temperature          47
#
# [83 rows x 3 columns]

# %% [markdown]
# ### Reshape DataFrame using Stack/Unstack

# %% [markdown]
# #### DF.stack(level=0, dropna=True)

# %% [markdown]
# Return a reshaped DataFrame or Series having a multi-level index with one or more new inner-most levels compared to the current DataFrame.

# %%
df_single = pd.DataFrame([[0, 1], [2, 3]],
                                    index=['cat', 'dog'],
                                    columns=['weight', 'height'])
df_single
# Out:
#      weight  height
# cat       0       1
# dog       2       3

# %%
df_single.stack()
# Out:
# cat  weight    0
#      height    1
# dog  weight    2
#      height    3
# dtype: int64

# %%
multicol1 = pd.MultiIndex.from_tuples([('weight', 'kg'),
                                       ('weight', 'pounds')])
df_multi = pd.DataFrame([[1, 2], [2, 4]],
                                    index=['cat', 'dog'],
                                    columns=multicol1)
df_multi
# Out:
#     weight
#         kg pounds
# cat      1      2
# dog      2      4

# %%
df_multi.stack()
# Out:
#             weight
# cat kg           1
#     pounds       2
# dog kg           2
#     pounds       4

# %%
df_multi.stack(level=0) #The first parameter controls which level or levels are stacked:
# Out:
#             kg  pounds
# cat weight   1       2
# dog weight   2       4

# %%
df_multi = df_multi.stack()
df_multi
# Out:
#             weight
# cat kg           1
#     pounds       2
# dog kg           2
#     pounds       4

# %%
df_multi = df_multi.unstack() 
df_multi
# Out:
#     weight
#         kg pounds
# cat      1      2
# dog      2      4
